# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Walker2d

# %%
# seed 0
iterations = np.arange(10) + 1
means = [-0.48262089490890503,1453.23974609375,3047.22216796875,5321.70263671875,4177.43896484375,
         4913.14599609375,5309.1982421875,5437.20458984375,5497.55322265625,5583.5068359375]
stds = [0.5223953723907471,1486.369873046875,1240.327392578125,88.79310607910156,1283.3265380859375,
       996.0233154296875,47.762237548828125,35.989925384521484,49.336341857910156, 51.67335510253906]
expert = 5566.845703125
bc_agent = -0.48262089490890503

# %%
plt.errorbar(iterations, means, yerr=stds, ecolor='red', label='DAgger Agent')
plt.ylabel('average return')
plt.xlabel('iteration')
plt.hlines(expert, label='Expert', xmin=1, xmax=10, colors=['green'])
plt.hlines(bc_agent, label='BC Agent', xmin=1, xmax=10, colors=['purple'])
plt.legend(loc='center right')
plt.grid()
plt.title('Walker2d (seed 0)')
plt.savefig('walker2d_seed_0')

# %%
# seed 1
iterations = np.arange(10) + 1
means = [340.41796875, 2.65514874458313, 423.74493408203125, 5230.35546875, 5303.2822265625,
        5393.837890625, 5439.13330078125, 5493.3125,5225.70263671875,4696.61279296875]
stds = [85.58679962158203, 16.247392654418945, 35.725521087646484, 52.80806350708008, 49.02265930175781,
       74.30326080322266, 90.92820739746094, 103.43856811523438,70.10346984863281,1419.4027099609375]
expert = 5566.845703125
bc_agent = 340.42

# %%
plt.errorbar(iterations, means, yerr=stds, ecolor='red', label='DAgger Agent')
plt.ylabel('average return')
plt.xlabel('iteration')
plt.hlines(expert, label='Expert', xmin=1, xmax=10, colors=['green'])
plt.hlines(bc_agent, label='BC Agent', xmin=1, xmax=10, colors=['purple'])
plt.legend(loc='center right')
plt.grid()
plt.title('Walker2d (seed 1)')
plt.savefig('walker2d_seed_1')

# %%
#Ant

# %%
# seed 0
iterations = np.arange(10) + 1
means = [4462.5966796875,4614.3349609375,4633.66943359375,4698.3818359375,4621.6904296875,
        4640.19140625,4876.5556640625,4635.4228515625,4643.45263671875,4807.2421875]
stds = [ 85.78620910644531,146.26524353027344,117.63533782958984,89.7395248413086,99.13113403320312,
       47.16849136352539,84.64434051513672,94.00296020507812,63.5677490234375,130.03321838378906]
expert = 4713.6533203125
bc_agent = 4462.5966796875

plt.errorbar(iterations, means, yerr=stds, ecolor='red', label='DAgger Agent')
plt.ylabel('average return')
plt.xlabel('iteration')
plt.hlines(expert, label='Expert', xmin=1, xmax=10, colors=['green'])
plt.hlines(bc_agent, label='BC Agent', xmin=1, xmax=10, colors=['purple'])
plt.legend(loc='center right')
plt.grid()
plt.title('Ant (seed 0)')
plt.savefig('ant_dag_seed_0')

# %%
# seed 1
iterations = np.arange(10) + 1
means = [4423.2060546875,3784.16650390625,4258.35693359375,4764.51416015625,4711.35888671875,
        4702.33837890625,4664.3876953125,4815.77734375,4774.4501953125,4771.16650390625]
stds = [182.40924072265625,1770.148681640625,753.8892822265625,131.37130737304688,99.7962646484375,
       87.58634185791016,139.86558532714844,83.26145935058594,99.4176025390625,53.44029235839844]
expert = 4713.6533203125
bc_agent = 4423.2060546875

plt.errorbar(iterations, means, yerr=stds, ecolor='red', label='DAgger Agent')
plt.ylabel('average return')
plt.xlabel('iteration')
plt.hlines(expert, label='Expert', xmin=1, xmax=10, colors=['green'])
plt.hlines(bc_agent, label='BC Agent', xmin=1, xmax=10, colors=['purple'])
plt.legend(loc='center right')
plt.grid()
plt.title('Ant (seed 1)')
plt.savefig('ant_dag_seed_1')

# %%
plt.errorbar(iterations, means, yerr=stds, ecolor='red', label='DAgger Agent')
plt.ylabel('average return')
plt.xlabel('iteration')
plt.hlines(expert, label='Expert', xmin=1, xmax=10, colors=['green'])
plt.hlines(bc_agent, label='BC Agent', xmin=1, xmax=10, colors=['purple'])
plt.legend(loc='center right')
plt.grid()
plt.title('Ant (seed: 1, cropped)')
plt.ylim((3700, 4900))
plt.savefig('ant_dag_seed_1_cropped')

# %%
# Experimenting with HParams

# %%
max_episode_length = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
average_return = [362.36004638671875,806.3886108398438,1261.089111328125,1722.0513916015625,
                 2173.102783203125,2635.103271484375,3094.0546875,3547.35595703125,
                 3994.925048828125,4462.5966796875]
std_return =[33.5434455871582,49.03853988647461,50.90401077270508,62.61528015136719,
            63.27391815185547,80.63726806640625,89.56908416748047,84.19972229003906,
            86.72592163085938,85.78620910644531]
plt.errorbar(max_episode_length, average_return, yerr=std_return, ecolor='red')
plt.ylabel('average return')
plt.xlabel('max episode length')
plt.grid()
plt.title('Ant (seed: 0)')
plt.savefig('ant_seed_0')
